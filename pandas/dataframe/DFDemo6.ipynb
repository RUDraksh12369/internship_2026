# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Movieratingdata1.csv")
pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)
print(df)
# Out:
#     USER_ID   MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR  \
# 0       1.0    4642044          Riot             2015
# 1       NaN        NaN            NaN             NaN
# 2       3.0  not value            NaN            2014
# 3       4.0    1390411            NaN            2015
# 4       5.0    6306064            NaN   not available
# 5       6.0    6306064            NaN     not mension
# 6       7.0    2719848            NaN            2015
# 7       8.0     462504            NaN            2006
# 8       9.0        NaN            NaN            2020
# 9      10.0     163225  The Revenant             2015
# 10     11.0    1663202            NaN            2015
# 11     12.0    1663202  The Revenant             2021
#
#                                                GENRES         RATING
# 0                                              Action            NaN
# 1                                                 NaN            NaN
# ...

# %%
print(df.isnull().sum())
# Out:
# USER_ID            1
# MOVIE_ID           2
# MOVIE_TITLE        9
# PRODUCTION_YEAR    1
# GENRES             3
# RATING             3
# dtype: int64

# %%
df.replace("not available",value=None,inplace=True)#replace not available to None

# %%
df.replace("not available",np.nan,inplace=True)#replace not available to nan

# %%
df.replace(["not available","not mension"],np.nan,inplace=True)#replace not available and not mension to nan

# %%
print(df)
# Out:
#     USER_ID   MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR  \
# 0       1.0    4642044          Riot             2015
# 1       NaN        NaN            NaN             NaN
# 2       3.0  not value            NaN            2014
# 3       4.0    1390411            NaN            2015
# 4       5.0    6306064            NaN            None
# 5       6.0    6306064            NaN             NaN
# 6       7.0    2719848            NaN            2015
# 7       8.0     462504            NaN            2006
# 8       9.0        NaN            NaN            2020
# 9      10.0     163225  The Revenant             2015
# 10     11.0    1663202            NaN            2015
# 11     12.0    1663202  The Revenant             2021
#
#                                                GENRES RATING
# 0                                              Action    NaN
# 1                                                 NaN    NaN
# 2                                                 NaN    NaN
# ...

# %%
df.replace('1390411','The Batman',inplace=True)#replace specific value
print(df)
# Out:
#     USER_ID    MOVIE_ID    MOVIE_TITLE PRODUCTION_YEAR  \
# 0       1.0     4642044          Riot             2015
# 1       NaN         NaN            NaN             NaN
# 2       3.0   not value            NaN            2014
# 3       4.0  The Batman            NaN            2015
# 4       5.0     6306064            NaN            None
# 5       6.0     6306064            NaN             NaN
# 6       7.0     2719848            NaN            2015
# 7       8.0      462504            NaN            2006
# 8       9.0         NaN            NaN            2020
# 9      10.0      163225  The Revenant             2015
# 10     11.0     1663202            NaN            2015
# 11     12.0     1663202  The Revenant             2021
#
#                                                GENRES RATING
# 0                                              Action    NaN
# 1                                                 NaN    NaN
# 2                                                 NaN    NaN
# ...
