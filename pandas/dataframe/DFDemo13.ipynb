# %%
import pandas as pd

# %%
people1 = {"First":["hardik","amit","sumit","raj"],
"Last":["shah","patel","thakkar","shah"],
"Email":["hardik","amit","sumit","raj"]}

# %%
df = pd.DataFrame(people1)
print(df)
# Out:
#     First     Last   Email
# 0  hardik     shah  hardik
# 1    amit    patel    amit
# 2   sumit  thakkar   sumit
# 3     raj     shah     raj

# %%
df["full name"] = df["First"]+ " "+df["Last"]
print(df)
# Out:
#     First     Last   Email      full name
# 0  hardik     shah  hardik    hardik shah
# 1    amit    patel    amit     amit patel
# 2   sumit  thakkar   sumit  sumit thakkar
# 3     raj     shah     raj       raj shah

# %%
df[["first","Last"]] = df["full name"].str.split(" ",expand=True)
print(df)
# Out:
#     First     Last   Email      full name   first
# 0  hardik     shah  hardik    hardik shah  hardik
# 1    amit    patel    amit     amit patel    amit
# 2   sumit  thakkar   sumit  sumit thakkar   sumit
# 3     raj     shah     raj       raj shah     raj

# %%
x = df.pop("full name")#pop is used to remove the column from the dataframe and return it as a series
print(x)
print(df)
