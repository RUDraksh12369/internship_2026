# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Movieratingdata1.csv")
df = pd.read_csv("Movieratingdata1.csv",na_values=["not available","not mension"])#replace specified strings with NaN beqfore reading the CSV file

# %%
pd.set_option("display.max_rows",None)#to display all rows
pd.set_option("display.max_columns",None)#to display all columns

# %%
#df = pd.read_csv("Movieratingdata1.csv",na_values={"PRODUCTION_YEAR":"not available"})
df = pd.read_csv("Movieratingdata1.csv",na_values={"PRODUCTION_YEAR":["not available","not mension"]})#replace specified strings with NaN in a particular column before reading the CSV file

# %%
print(df)
# Out:
#     USER_ID   MOVIE_ID    MOVIE_TITLE  PRODUCTION_YEAR  \
# 0       1.0    4642044          Riot            2015.0
# 1       NaN        NaN            NaN              NaN
# 2       3.0  not value            NaN           2014.0
# 3       4.0    1390411            NaN           2015.0
# 4       5.0    6306064            NaN              NaN
# 5       6.0    6306064            NaN              NaN
# 6       7.0    2719848            NaN           2015.0
# 7       8.0     462504            NaN           2006.0
# 8       9.0        NaN            NaN           2020.0
# 9      10.0     163225  The Revenant            2015.0
# 10     11.0    1663202            NaN           2015.0
# 11     12.0    1663202  The Revenant            2021.0
#
#                                                GENRES         RATING
# 0                                              Action            NaN
# 1                                                 NaN            NaN
# ...
