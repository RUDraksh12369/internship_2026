# %%
import pandas as pd

# %%
users = pd.Series([21,22,23,21,24,25],index=["amit","raj","sumit","rohit","jay","virat"])
print(users.sample())
# Out:
# amit    21
# dtype: int64

# %%
print(users+1)
print(users-1)
print(users*2)
print(users/2)
# Out:
# amit     22
# raj      23
# sumit    24
# rohit    22
# jay      25
# virat    26
# dtype: int64
# amit     20
# raj      21
# sumit    22
# rohit    20
# jay      23
# virat    24
# dtype: int64
# amit     42
# raj      44
# sumit    46
# rohit    42
# jay      48
# virat    50
# dtype: int64
# amit     10.5
# raj      11.0
# sumit    11.5
# rohit    10.5
# jay      12.0
# virat    12.5
# dtype: float64
