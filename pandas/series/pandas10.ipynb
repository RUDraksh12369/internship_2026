# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s = s.apply(lambda x: x * 2)
print(s)
# Out:
# 0    20
# 1    40
# 2    60
# 3    80
# dtype: int64

# %%
users = pd.Series(['user1', 'user2',  'user3'])
print(users)
# Out:
# 0    user1
# 1    user2
# 2    user3
# dtype: object

# %%
users = users.apply(lambda x: x.upper())
print(users)
# Out:
# 0    USER1
# 1    USER2
# 2    USER3
# dtype: object
