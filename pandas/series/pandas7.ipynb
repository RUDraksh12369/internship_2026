# %%
import pandas as pd

# %%
s = pd.Series([10,20,30,40,50])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s.sum())
print(s.mean())
print(s.max())
print(s.min())
print(s.std())
print(s.var())# Variance
print(s.count())# Count of non-null values
# Out:
# 150
# 30.0
# 50
# 10
# 15.811388300841896
# 250.0
# 5
