# %%
import pandas as pd

# %%
s = pd.Series(["apple", "banana", "cherry",12])
print(s)
# Out:
# 0     apple
# 1    banana
# 2    cherry
# 3        12
# dtype: object

# %%
s = s.str.upper()
print(s)
# Out:
# 0     APPLE
# 1    BANANA
# 2    CHERRY
# 3       NaN
# dtype: object

# %%
s = s.str.startswith("A")
print(s)
# Out:
# 0     True
# 1    False
# 2    False
# 3      NaN
# dtype: object
