# %% [markdown]
# in website check trafic for weekdays using heatmap

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
Trafic = np.random.randint(50, 500, (7, 24))
days = ["sun","mon","tue","wed","thu","fri","sat"]

# %%
sns.heatmap(Trafic,cmap="YlOrRd")
# Out:
# <Axes: >

# %% [markdown]
# in seaborn line,bar, heamap,boxplot,count plot,scatter,pairplot,violin perfrom this graphs
# in subplot use clean data to create 3 graphs
