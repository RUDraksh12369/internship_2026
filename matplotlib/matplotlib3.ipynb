# %%
import matplotlib.pyplot as plt

# %%
hours =[1,2,3,4,5,6]
boys_marks  = [35,40,50,65,70,75]
girsl_marks = [36,42,55,70,75,80]

# %%
plt.scatter(hours ,boys_marks ,color = "Red" ,label = "Boys")
plt.scatter(hours ,girsl_marks,color = "Blue" ,label = "girls")

# %%
hours =[1,2,3,4,5,6]
marks =[35,40,50,65,70,75]

# %%
plt.scatter(hours,marks,marker="*")
plt.plot(hours,marks,label="Trend Line")
